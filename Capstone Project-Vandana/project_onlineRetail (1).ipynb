# %% [markdown]
# #              Online Retail store project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("OnlineRetail (3).csv",encoding= 'unicode_escape')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37309 entries, 0 to 37308
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    37309 non-null  object
#  1   StockCode    37309 non-null  object
#  2   Description  37192 non-null  object
#  3   Quantity     37309 non-null  int64
#  4   InvoiceDate  37309 non-null  object
#  5   UnitPrice    37308 non-null  float64
#  6   CustomerID   24429 non-null  float64
#  7   Country      37308 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.3+ MB
# None
# (37309, 8)

# %%
#checking null values
df.isna().sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description      117
# Quantity           0
# InvoiceDate        0
# UnitPrice          1
# CustomerID     12880
# Country            1
# dtype: int64

# %%
df['CustomerID']=df['CustomerID'].fillna(0)
df=df.dropna()
df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 37303    539456    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE         1
# 37304    539456    85135C             RED DRAGONFLY HELICOPTER         2
# 37305    539456     22095                 LADS ONLY TISSUE BOX         1
# 37306    539456   15056BL              EDWARDIAN PARASOL BLACK         1
# 37307    539456     20679                EDWARDIAN PARASOL RED         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 37303  12/17/2010 17:23       2.95     16885.0  United Kingdom
# 37304  12/17/2010 17:23       7.95     16885.0  United Kingdom
# 37305  12/17/2010 17:23       1.25     16885.0  United Kingdom
# 37306  12/17/2010 17:23       5.95     16885.0  United Kingdom
# 37307  12/17/2010 17:23       5.95     16885.0  United Kingdom
#
# [37191 rows x 8 columns]

# %%
#graph between country and quantity
fig = plt.figure(figsize =(15, 7))
plt.bar(df['Country'],df['Quantity'],color='g')
plt.xlabel('country')
plt.ylabel('Quantity')
plt.show()

# %%
#checking quantity having values less than 0
neg_quantity=df.loc[df['Quantity'] < 0,:]
neg_quantity
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 141     C536379         D                           Discount        -1
# 154     C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235     C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236     C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237     C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...         ...       ...                                ...       ...
# 34512   C539402     21527  RED RETROSPOT TRADITIONAL TEAPOT         -1
# 34591   C539409      POST                            POSTAGE        -1
# 36165   C539438     22655        VINTAGE RED KITCHEN CABINET        -1
# 36300   C539448     20802      SMALL GLASS SUNDAE DISH CLEAR       -36
# 36301   C539448     20803       SMALL PINK GLASS SUNDAE DISH       -36
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141      12/1/2010 9:41      27.50     14527.0  United Kingdom
# 154      12/1/2010 9:49       4.65     15311.0  United Kingdom
# 235     12/1/2010 10:24       1.65     17548.0  United Kingdom
# 236     12/1/2010 10:24       0.29     17548.0  United Kingdom
# 237     12/1/2010 10:24       0.29     17548.0  United Kingdom
# ...                 ...        ...         ...             ...
# 34512  12/17/2010 12:19       6.95     17315.0  United Kingdom
# 34591  12/17/2010 12:58      18.00     12720.0         Germany
# 36165  12/17/2010 15:11     295.00     16607.0  United Kingdom
# 36300  12/17/2010 16:25       0.42     15157.0  United Kingdom
# 36301  12/17/2010 16:25       0.42     15157.0  United Kingdom
#
# [604 rows x 8 columns]

# %%
# deleting all rows having less than zeroes values in Quality column
df= df[(df.Quantity>0)]
df
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365     71053                  WHITE METAL LANTERN         6
# 2        536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...       ...                                  ...       ...
# 37303    539456    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE         1
# 37304    539456    85135C             RED DRAGONFLY HELICOPTER         2
# 37305    539456     22095                 LADS ONLY TISSUE BOX         1
# 37306    539456   15056BL              EDWARDIAN PARASOL BLACK         1
# 37307    539456     20679                EDWARDIAN PARASOL RED         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 37303  12/17/2010 17:23       2.95     16885.0  United Kingdom
# 37304  12/17/2010 17:23       7.95     16885.0  United Kingdom
# 37305  12/17/2010 17:23       1.25     16885.0  United Kingdom
# 37306  12/17/2010 17:23       5.95     16885.0  United Kingdom
# 37307  12/17/2010 17:23       5.95     16885.0  United Kingdom
#
# [36587 rows x 8 columns]

# %%
#checking duplicate entries
print('Duplicate entries: {}'.format(df.duplicated().sum()))
print('{}% rows are duplicate.'.format(round((df.duplicated().sum()/df.shape[0])*100),2))
df.drop_duplicates(inplace = True)
# Out:
# Duplicate entries: 464
# 1% rows are duplicate.
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36123 entries, 0 to 37307
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    36123 non-null  object
#  1   StockCode    36123 non-null  object
#  2   Description  36123 non-null  object
#  3   Quantity     36123 non-null  int64
#  4   InvoiceDate  36123 non-null  object
#  5   UnitPrice    36123 non-null  float64
#  6   CustomerID   36123 non-null  float64
#  7   Country      36123 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.5+ MB

# %%
#deleting unneccessary column
df=df[['InvoiceNo','StockCode','Quantity','UnitPrice','CustomerID','Country']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36123 entries, 0 to 37307
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   InvoiceNo   36123 non-null  object
#  1   StockCode   36123 non-null  object
#  2   Quantity    36123 non-null  int64
#  3   UnitPrice   36123 non-null  float64
#  4   CustomerID  36123 non-null  float64
#  5   Country     36123 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.9+ MB

# %%
# Import label encoder
from sklearn.preprocessing import LabelEncoder
# label_encoder object knows how to understand word labels.
le = LabelEncoder()
df['InvoiceNo']= le.fit_transform(df['InvoiceNo'])
df['StockCode']= le.fit_transform(df['StockCode'])
df['Country']= le.fit_transform(df['Country'])
df
# Out:
#        InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country
# 0              0       2376         6       2.55     17850.0       21
# 1              0       1894         6       3.39     17850.0       21
# 2              0       2051         8       2.75     17850.0       21
# 3              0       2015         6       3.39     17850.0       21
# 4              0       2014         6       3.39     17850.0       21
# ...          ...        ...       ...        ...         ...      ...
# 37303       1376       2021         1       2.95     16885.0       21
# 37304       1376       2397         2       7.95     16885.0       21
# 37305       1376        905         1       1.25     16885.0       21
# 37306       1376         15         1       5.95     16885.0       21
# 37307       1376        113         1       5.95     16885.0       21
#
# [36123 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler().fit_transform(df)
sc
# Out:
# array([[-1.83887602,  1.74112414, -0.072476  , -0.02950711,  1.03072533,
#          0.21543757],
#        [-1.83887602,  1.00837167, -0.072476  , -0.01817837,  1.03072533,
#          0.21543757],
#        [-1.83887602,  1.2470483 , -0.0191487 , -0.02680979,  1.03072533,
#          0.21543757],
#        ...,
#        [ 1.74462251, -0.49513911, -0.20579424, -0.04703969,  0.90292258,
#          0.21543757],
#        [ 1.74462251, -1.84814679, -0.20579424,  0.01634732,  0.90292258,
#          0.21543757],
#        [ 1.74462251, -1.69916393, -0.20579424,  0.01634732,  0.90292258,
#          0.21543757]])

# %%
from sklearn.cluster import KMeans
#elbow mothod
clusters=[2,3,4,5,6,7,8,9,10]
ssd=[]
for i in clusters:
    model_clus=KMeans(n_clusters=i,random_state=50,max_iter=150)
    model_clus.fit(sc)
    ssd.append(model_clus.inertia_)
plt.plot(clusters,ssd);
print(clusters)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
labels = kmeans.fit(sc)
cluster_labels = kmeans.labels_
df['Cluster_Id']=cluster_labels
df
# Out:
#        InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  \
# 0              0       2376         6       2.55     17850.0       21
# 1              0       1894         6       3.39     17850.0       21
# 2              0       2051         8       2.75     17850.0       21
# 3              0       2015         6       3.39     17850.0       21
# 4              0       2014         6       3.39     17850.0       21
# ...          ...        ...       ...        ...         ...      ...
# 37303       1376       2021         1       2.95     16885.0       21
# 37304       1376       2397         2       7.95     16885.0       21
# 37305       1376        905         1       1.25     16885.0       21
# 37306       1376         15         1       5.95     16885.0       21
# 37307       1376        113         1       5.95     16885.0       21
#
#        Cluster_Id
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ...           ...
# 37303           2
# 37304           2
# 37305           2
# 37306           2
# 37307           2
#
# [36123 rows x 7 columns]

# %%
# define and map colors
colors = ['green', 'red', 'blue','yellow']
df['c'] = df.Cluster_Id.map({0:colors[0],1:colors[1],2:colors[2],3:colors[3]})
df
# Out:
#        InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID  Country  \
# 0              0       2376         6       2.55     17850.0       21
# 1              0       1894         6       3.39     17850.0       21
# 2              0       2051         8       2.75     17850.0       21
# 3              0       2015         6       3.39     17850.0       21
# 4              0       2014         6       3.39     17850.0       21
# ...          ...        ...       ...        ...         ...      ...
# 37303       1376       2021         1       2.95     16885.0       21
# 37304       1376       2397         2       7.95     16885.0       21
# 37305       1376        905         1       1.25     16885.0       21
# 37306       1376         15         1       5.95     16885.0       21
# 37307       1376        113         1       5.95     16885.0       21
#
#        Cluster_Id     c
# 0               2  blue
# 1               2  blue
# 2               2  blue
# 3               2  blue
# 4               2  blue
# ...           ...   ...
# 37303           2  blue
# 37304           2  blue
# 37305           2  blue
# 37306           2  blue
# 37307           2  blue
#
# [36123 rows x 8 columns]

# %%
df.plot.scatter(x='Country',y='Quantity',c=df.c,s=10)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Quantity'>

# %%
df.plot.scatter(x='Country',y='StockCode',c=df.c,s=10)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='StockCode'>
